# %% [markdown]
# # LANOT_curso_PR_incendios
#
# Curso especializado de percepción remota aplicado a la detección y análisis de incendios forestales.
#
# LANOT, Instituto de Geografía, UNAM.
#
# 26 y 27 de junio de 2023.
#
# Demostración y ejercicio: 16 de junio de 2023
# Entrenamiento NASA-ARSET, México

# %% [markdown]
# ## Google Earth Engine
#
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # Sentinel-2
# ![Alt text](image.png)
# ![Alt text](image-2.png)
# ![Alt text](image-1.png)
# ![Alt text](image-3.png)
# ![Alt text](image-4.png)

# %% [markdown]
# Link
#
# https://code.earthengine.google.com/9058afc2c78f93170d95348039a49bda?noload=true
#
# https://code.earthengine.google.com/?accept_repo=users/urielzan/LANOT_curso_PR_incendios
